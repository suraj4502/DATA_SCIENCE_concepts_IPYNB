# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading file
ds=pd.read_csv('/content/Salaries.csv')

# %%
ds.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
ds.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
#getting the first 50 rows from the dataset
ds.head(50)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
ds.head(20)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
#list the types of the columns
ds.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
#list the rows labels and column names
ds.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
#number of dimensions
ds.ndim
# Out:
# 2

# %%
#Return the number of rows if Series. Otherwise return the number of rows times number of columns if DataFrame.
#rows * columns
ds.size
# Out:
# 468

# %%
#show the colums
ds.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
#shows rows and columns
ds.shape
# Out:
# (78, 6)

# %%
#Return a Numpy representation of the DataFrame.
ds.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %%
#This method prints information about a DataFrame including the index dtype and columns,non-null values and memory usage.
ds.info
# Out:
# <bound method DataFrame.info of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
#shows dataframe methods 
#()are required
#methods give data about 
dir(ds)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
#to get only numeric columns
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
ds.select_dtypes(include=numerics)
#we can also use ds[('column1','column2',..,'column n')]
# Out:
#     phd  service  salary
# 0    56       49  186960
# 1    12        6   93000
# 2    23       20  110515
# 3    40       31  131205
# 4    20       18  104800
# ..  ...      ...     ...
# 73   18       10  105450
# 74   19        6  104542
# 75   17       17  124312
# 76   28       14  109954
# 77   23       15  109646
#
# [78 rows x 3 columns]

# %%
#Mean of the top 50 rows
ds.head(50).mean()
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
#slicing a dataset
#method1= df['column name'] it gives a series
#method2= df.column_name
#method3=df[('column_name')] it gives a dataframe
ds[('salary')]
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
phd=ds[('phd')]
phd.describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
#groupby method=Group DataFrame using a mapper or by a Series of columns.
group=ds.groupby('rank')#here we grouped using rank 
group.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
#filtering in python
#Q. print the rows wehere salary is more than 120k
ds[ds['salary']>120000]
#ds['salary']>120000 this gives bollean values
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
#for discipline =B
ds['discipline']=="B"
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 73     True
# 74     True
# 75     True
# 76    False
# 77    False
# Name: discipline, Length: 78, dtype: bool

# %%
#sliced the data usinf two parameters
ds[(ds['rank']=="Prof") & (ds['discipline']=="A")]
# Out:
#     rank discipline  phd  service     sex  salary
# 1   Prof          A   12        6    Male   93000
# 2   Prof          A   23       20    Male  110515
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 8   Prof          A   29       19    Male   94350
# 9   Prof          A   51       51    Male   57800
# 18  Prof          A   19        7    Male  107300
# 19  Prof          A   29       27    Male  150500
# 21  Prof          A   33       30    Male  103106
# 24  Prof          A   30       23    Male   91100
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 32  Prof          A   27       19    Male  103275
# 37  Prof          A   20        8    Male  102000
# 40  Prof          A   39       36  Female  137000
# 52  Prof          A   12        0  Female  105000
# 63  Prof          A   29       27  Female   91000
# ...

# %%
#iloc method(intigerlocation)
ds
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
ds.iloc[0:4]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205

# %%
ds.iloc[2:7]
# Out:
#         rank discipline  phd  service   sex  salary
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285

# %%
#last 3 columns
ds.iloc[:, -3:]
# Out:
#     service     sex  salary
# 0        49    Male  186960
# 1         6    Male   93000
# 2        20    Male  110515
# 3        31    Male  131205
# 4        18    Male  104800
# ..      ...     ...     ...
# 73       10  Female  105450
# 74        6  Female  104542
# 75       17  Female  124312
# 76       14  Female  109954
# 77       15  Female  109646
#
# [78 rows x 3 columns]

# %%
ds.iloc[1:6,0:3]
# Out:
#    rank discipline  phd
# 1  Prof          A   12
# 2  Prof          A   23
# 3  Prof          A   40
# 4  Prof          B   20
# 5  Prof          A   20

# %% [markdown]
# ## Aggregation functions

# %%
ds[["phd","salary"]].agg(['min','mean','max'])
# Out:
#             phd         salary
# min    1.000000   57800.000000
# mean  19.705128  108023.782051
# max   56.000000  186960.000000
